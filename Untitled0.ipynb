# %%
import os

file_path = "/content/AllIndiaPincodeDataSet.csv"

print("Exists:", os.path.exists(file_path))
print("Size:", os.path.getsize(file_path), "bytes")
# Out:
# Exists: True
# Size: 23066077 bytes

# %%
import pandas as pd

# %%
df = pd.read_csv(file_path)

# %%
df.shape
# Out:
# (165627, 11)

# %%
df.head()
# Out:
#          circlename        regionname       divisionname    officename  \
# 0  Telangana Circle  Hyderabad Region  Adilabad Division  Kothimir B.O
# 1  Telangana Circle  Hyderabad Region  Adilabad Division  Papanpet B.O
# 2  Telangana Circle  Hyderabad Region  Adilabad Division    Kukuda B.O
# 3  Telangana Circle  Hyderabad Region  Adilabad Division  Bareguda B.O
# 4  Telangana Circle  Hyderabad Region  Adilabad Division     Mosam B.O
#
#    pincode officetype  delivery                district  statename  \
# 0   504273         BO  Delivery  KUMURAM BHEEM ASIFABAD  TELANGANA
# 1   504299         BO  Delivery  KUMURAM BHEEM ASIFABAD  TELANGANA
# 2   504299         BO  Delivery  KUMURAM BHEEM ASIFABAD  TELANGANA
# 3   504296         BO  Delivery  KUMURAM BHEEM ASIFABAD  TELANGANA
# 4   504296         BO  Delivery  KUMURAM BHEEM ASIFABAD  TELANGANA
#
#      latitude   longitude
# 0  19.3638689  79.5376658
# 1  19.4764899  79.5839230
# 2         NaN         NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165627 entries, 0 to 165626
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   circlename    165627 non-null  object
#  1   regionname    165312 non-null  object
#  2   divisionname  165627 non-null  object
#  3   officename    165627 non-null  object
#  4   pincode       165627 non-null  int64
#  5   officetype    165627 non-null  object
#  6   delivery      165627 non-null  object
#  7   district      164912 non-null  object
#  8   statename     164912 non-null  object
#  9   latitude      153620 non-null  object
#  10  longitude     153625 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 13.9+ MB

# %%
for i, col in enumerate(df.columns, start=1):
    print(f"{i}. {col}")
# Out:
# 1. circlename
# 2. regionname
# 3. divisionname
# 4. officename
# 5. pincode
# 6. officetype
# 7. delivery
# 8. district
# 9. statename
# 10. latitude
# 11. longitude

# %%
for col in df.columns:
    print(repr(col))
# Out:
# 'circlename'
# 'regionname'
# 'divisionname'
# 'officename'
# 'pincode'
# 'officetype'
# 'delivery'
# 'district'
# 'statename'
# 'latitude'
# 'longitude'

# %%
df['pincode'].describe()
# Out:
# count    165627.000000
# mean     506840.727333
# std      207001.361694
# min      110001.000000
# 25%      341301.000000
# 50%      503180.000000
# 75%      690504.500000
# max      900099.000000
# Name: pincode, dtype: float64

# %%
df['pincode'].nunique()
# Out:
# 19586

# %%
df.groupby('pincode').size().describe()
# Out:
# count    19586.000000
# mean         8.456397
# std          7.254741
# min          1.000000
# 25%          3.000000
# 50%          7.000000
# 75%         11.000000
# max        153.000000
# dtype: float64

# %%
# We are testing whether multiple post offices exist under a single PIN code (248002)
# Specifically, we are searching for "Clement Town" within PIN code 248002 to verify
# if the dataset correctly maps multiple offices to one PIN code.

df[(df['pincode'] == 248002) & (df['officename'].str.contains("Clement Town", case=False, na=False))]
# Out:
# Empty DataFrame
# Columns: [circlename, regionname, divisionname, officename, pincode, officetype, delivery, district, statename, latitude, longitude]
# Index: []

# %%
df[df['pincode'] == 248002]
# Out:
#                 circlename          regionname       divisionname  \
# 65204   Uttarakhand Circle  DivReportingCircle  Dehradun Division
# 132048  Uttarakhand Circle  DivReportingCircle  Dehradun Division
# 155723  Uttarakhand Circle  DivReportingCircle  Dehradun Division
#
#             officename  pincode officetype      delivery  district  \
# 65204   Clementtown SO   248002         PO      Delivery  DEHRADUN
# 132048  Turner Road SO   248002         PO  Non Delivery  DEHRADUN
# 155723    Mohbewala BO   248002         BO      Delivery  DEHRADUN
#
#           statename    latitude   longitude
# 65204   UTTARAKHAND  30.2650833  78.0012778
# 132048  UTTARAKHAND  30.2871111  77.9960278
# 155723  UTTARAKHAND  30.4836500  77.9359100
